# %%
import pandas as pd
df = pd.read_csv('sample_survey_results_public.csv')
cols_needed = ['Hobbyist','Age','ConvertedComp','Country','Employment','LanguageWorkedWith','WorkWeekHrs']
df = df[cols_needed]

# %%
result = df.groupby('Country').apply(lambda x: pd.Series({
    'NumResponded': len(x),
    'KnowsPython': x['LanguageWorkedWith'].str.contains('Python', na = False).sum(),
    'knowsJavaScript': x['LanguageWorkedWith'].str.contains('JavaScript', na = False).sum(),
    'KnowsJava': x['LanguageWorkedWith'].str.contains('Java', na = False).sum(),
    'ProgrammingAsHobby': (x['Hobbyist'] == 'Yes').sum(),
    'NumStudent': x['Employment'].str.contains('Student', na = False).sum(),
    'AverageAge': x['Age'].mean(),
    'AverageAnnualSalary(USD)': x['ConvertedComp'].mean(),
    'AverageWorkingWeekHours': x['WorkWeekHrs'].mean()
}))

result.to_csv('test.csv')
# Out:
# C:\Users\Nishat\AppData\Local\Temp\ipykernel_5836\1233781500.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = df.groupby('Country').apply(lambda x: pd.Series({

# %%
result
# Out:
#                                       NumResponded  KnowsPython  \
# Country
# Afghanistan                                   21.0          5.0
# Albania                                        7.0          1.0
# Algeria                                       24.0         13.0
# Andorra                                        2.0          0.0
# Angola                                         3.0          0.0
# ...                                            ...          ...
# Venezuela, Bolivarian Republic of...          19.0          9.0
# Viet Nam                                      85.0         19.0
# Yemen                                          2.0          0.0
# Zambia                                         7.0          1.0
# Zimbabwe                                       6.0          2.0
#
#                                       knowsJavaScript  KnowsJava  \
# Country
# Afghanistan                                      10.0       12.0
# ...
